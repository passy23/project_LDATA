# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('celeba_buffalo_l.csv')
df.head()
# Out:
#    image_name  5_o_Clock_Shadow  Arched_Eyebrows  Bags_Under_Eyes  Bald  \
# 0  000001.jpg                -1                1               -1    -1
# 1  000004.jpg                -1               -1               -1    -1
# 2  000006.jpg                -1                1               -1    -1
# 3  000008.jpg                 1                1                1    -1
# 4  000018.jpg                -1                1               -1    -1
#
#    Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  embedding_503  \
# 0     -1        -1        -1          -1          -1  ...      -1.484989
# 1     -1        -1        -1          -1          -1  ...      -0.510537
# 2     -1         1        -1          -1          -1  ...      -0.645637
# 3     -1         1        -1           1          -1  ...       0.983840
# 4     -1        -1         1          -1           1  ...      -0.168269
#
#    embedding_504  embedding_505  embedding_506  embedding_507  embedding_508  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30012 entries, 0 to 30011
# Columns: 553 entries, image_name to id
# dtypes: float64(512), int64(40), object(1)
# memory usage: 126.6+ MB
# None

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# image_name          0
# 5_o_Clock_Shadow    0
# Arched_Eyebrows     0
# Bags_Under_Eyes     0
# Bald                0
#                    ..
# embedding_508       0
# embedding_509       0
# embedding_510       0
# embedding_511       0
# id                  0
# Length: 553, dtype: int64

# %%
from PIL import Image
data_path = '../celeba'
# Example: Displaying sample images
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

for i, ax in enumerate(axes.flat):
    img_path = data_path + '/img_celeba/' + df.iloc[i]['image_name']
    img = Image.open(img_path)
    ax.imshow(img)
    ax.axis('off')

plt.show()

# %%
df.iloc[:, 502:532].describe()
# Out:
#        embedding_462  embedding_463  embedding_464  embedding_465  \
# count   30012.000000   30012.000000   30012.000000   30012.000000
# mean       -0.005073      -0.065604      -0.114656      -0.104962
# std         0.985831       0.954833       0.961047       0.880761
# min        -4.344406      -4.438943      -4.017321      -3.414075
# 25%        -0.671426      -0.707610      -0.767734      -0.701015
# 50%        -0.010227      -0.067770      -0.123201      -0.097283
# 75%         0.655682       0.582408       0.525628       0.487742
# max         3.786302       3.643735       4.457612       3.745844
#
#        embedding_466  embedding_467  embedding_468  embedding_469  \
# count   30012.000000   30012.000000   30012.000000   30012.000000
# mean        0.105498       0.069139       0.000100       0.117418
# std         0.965947       0.986419       0.983495       0.959453
# min        -4.966735      -3.982499      -4.479791      -3.606959
# ...

# %%
# Example: Histogram of embeddings columns
df.iloc[:, 503:510].hist(bins=20, figsize=(12, 8))
plt.show()

# %%
# Example: Creating a correlation heatmap
# Explore relationships between numerical features
correlation_matrix =  df.iloc[:, 503:510].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Attribute Correlation Heatmap of embeddings')
# Out:
#                embedding_463  embedding_464  embedding_465  embedding_466  \
# embedding_463       1.000000      -0.043853      -0.018654      -0.030273
# embedding_464      -0.043853       1.000000       0.032634       0.086132
# embedding_465      -0.018654       0.032634       1.000000      -0.077665
# embedding_466      -0.030273       0.086132      -0.077665       1.000000
# embedding_467       0.009459       0.038535       0.037621      -0.036777
# embedding_468       0.035896       0.009490      -0.012414      -0.098013
# embedding_469       0.015970      -0.039175       0.024301      -0.019738
#
#                embedding_467  embedding_468  embedding_469
# embedding_463       0.009459       0.035896       0.015970
# embedding_464       0.038535       0.009490      -0.039175
# embedding_465       0.037621      -0.012414       0.024301
# embedding_466      -0.036777      -0.098013      -0.019738
# embedding_467       1.000000       0.033079      -0.022531
# ...

# %%
# Explore relationships between categorical features
categorical_columns =['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair']
for col in categorical_columns:
    print(pd.crosstab(index=df[col], columns='count'))
# Out:
# col_0             count
# 5_o_Clock_Shadow
# -1                26252
#  1                 3760
# col_0            count
# Arched_Eyebrows
# -1               17420
#  1               12592
# col_0            count
# Bags_Under_Eyes
# -1               21609
#  1                8403
# col_0  count
# Bald
# -1     29589
#  1       423
# col_0  count
# Bangs
# -1     24552
#  1      5460
# col_0     count
# Big_Lips
# -1        21315
#  1         8697
# col_0     count
# Big_Nose
# -1        21457
#  1         8555
# col_0       count
# Black_Hair
# -1          23647
#  1           6365
# col_0       count
# Blond_Hair
# -1          24611
#  1           5401

# %%
# Plot bar plots for each categorical column
for col in categorical_columns:
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Visualize embeddings using scatter plot
sns.scatterplot(x='embedding_503', y='embedding_504', hue='Bangs', data=df)
plt.title('Scatter Plot of Embeddings')
plt.show()

# %%
# Example: Box plot for comparing features from different models
sns.boxplot(x='embedding_503', y='Bags_Under_Eyes', data=df)
plt.title('Comparison of Bags_Under_Eyes Across Models')
plt.show()

# %%
# Example: Pair plot for comparing features within the same latent space
sns.pairplot(df[['Bangs', 'Big_Lips', 'Big_Nose']])
plt.title('Pair Plot of Features within Latent Space')
plt.show()
